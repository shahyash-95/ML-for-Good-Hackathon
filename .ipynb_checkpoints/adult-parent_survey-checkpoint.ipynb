# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## read Adult data

# %%
adult_April20 = pd.read_csv('Data/ProlificAcademic/updated_data/April/CRISIS_Adult_April_2020.csv')
adult_May20 = pd.read_csv('Data/ProlificAcademic/updated_data/May/CRISIS_Adult_May_2020.csv',index_col='ID')
adult_Nov20 = pd.read_csv('Data/ProlificAcademic/updated_data/November/CRISIS_Adult_November_2020.csv',index_col='ID')
adult_April21 = pd.read_csv('Data/ProlificAcademic/updated_data/April_21/CRISIS_Adult_April_2021.csv',index_col='ID')
# Out:
# C:\Users\MSUSERSL123\anaconda3\envs\crisisml\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\MSUSERSL123\anaconda3\envs\crisisml\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,77,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## read parent data

# %%
parent_April20 = pd.read_csv('Data/ProlificAcademic/updated_data/April/CRISIS_Parent_April_2020.csv',index_col='ID')
parent_May20 = pd.read_csv('Data/ProlificAcademic/updated_data/May/CRISIS_Parent_May_2020.csv',index_col='ID')
parent_Nov20 = pd.read_csv('Data/ProlificAcademic/updated_data/November/CRISIS_Parent_November_2020.csv',index_col='ID')
parent_April21 = pd.read_csv('Data/ProlificAcademic/updated_data/April_21/CRISIS_Parent_April_2021.csv',index_col='ID')

# %%
id_key = pd.read_csv('Data/ProlificAcademic/updated_data/ID_Key.csv')

# %%
parent_April20.shape
# Out:
# (2244, 244)

# %%
parent_April20.head()
# Out:
#                    timestamp1  country   age  sex sex_other  \
# ID
# 00028667  2020-04-13 09:21:00    186.0  52.0  1.0       NaN
# 003f374a  2020-04-09 18:28:00    186.0  35.0  1.0       NaN
# 00662b3f  2020-04-15 12:18:00    186.0  32.0  2.0       NaN
# 00991770  2020-04-09 19:07:00    186.0  30.0  1.0       NaN
# 00b76a23  2020-04-09 17:16:00    187.0  27.0  1.0       NaN
#
#           raceethnicity___1  raceethnicity___2  raceethnicity___3  \
# ID
# 00028667                  1                  0                  0
# 003f374a                  1                  0                  0
# 00662b3f                  1                  0                  0
# 00991770                  1                  0                  0
# 00b76a23                  1                  0                  0
#
#           raceethnicity___4  raceethnicity___5  ...  fam_impact_hlth  fam_dx  \
# ID                                              ...
# ...

# %%
id_key.shape
# Out:
# (5940, 3)

# %%
id_key.dropna(axis = 0, how ='any',inplace=True)

# %%
id_key.columns
# Out:
# Index(['OID', 'Adult_ID', 'Parent_ID'], dtype='object')

# %%
adult_April20.head()
# Out:
#                    timestamp1  country   age  sex sex_other  \
# ID
# 00136f50  2020-04-09 00:13:00    187.0  18.0  1.0       NaN
# 003db2d0  2020-04-09 16:39:00    187.0  34.0  1.0       NaN
# 005a1e3e  2020-04-09 17:10:00    187.0  24.0  2.0       NaN
# 005ef0c4  2020-04-09 16:18:00    187.0  51.0  1.0       NaN
# 00601150  2020-04-09 16:04:00    187.0  38.0  2.0       NaN
#
#           raceethnicity___1  raceethnicity___2  raceethnicity___3  \
# ID
# 00136f50                  0                  0                  0
# 003db2d0                  0                  0                  0
# 005a1e3e                  0                  0                  0
# 005ef0c4                  1                  0                  0
# 00601150                  0                  0                  0
#
#           raceethnicity___4  raceethnicity___5  ...  fam_impact_hlth  fam_dx  \
# ID                                              ...
# ...

# %%
April20_surveys_df = pd.merge(adult_April20, id_key, left_on="ID", right_on="Adult_ID").merge(parent_April20,left_on="Parent_ID",right_on="ID",how="inner",suffixes=('_adult','_parent'))
May20_surveys_df = pd.merge(adult_May20, id_key, left_on="ID", right_on="Adult_ID").merge(parent_May20,left_on="Parent_ID",right_on="ID",how="inner",suffixes=('_adult','_parent'))
Nov20_surveys_df = pd.merge(adult_Nov20, id_key, left_on="ID", right_on="Adult_ID").merge(parent_Nov20,left_on="Parent_ID",right_on="ID",how="inner",suffixes=('_adult','_parent'))
April21_surveys_df = pd.merge(adult_April21, id_key, left_on="ID", right_on="Adult_ID").merge(parent_April21,left_on="Parent_ID",right_on="ID",how="inner",suffixes=('_adult','_parent'))

# %%
Nov20_surveys_df.shape
# Out:
# (223, 577)
